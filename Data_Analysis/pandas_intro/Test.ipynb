# %%
import pandas
df=pandas.read_csv('alldata.csv')
df
# Out:
#            RT Idiom_lang relatedness   lang_group  subj
# 0    0.763036   CH-idiom     Control    Bilingual     1
# 1    0.780152   CH-idiom     Control    Bilingual     2
# 2    0.771651   CH-idiom     Control    Bilingual     3
# 3    0.786284   CH-idiom     Control    Bilingual     4
# 4    1.155898   CH-idiom     Control    Bilingual     5
# 5    0.668348   CH-idiom     Control    Bilingual     6
# 6    0.966810   CH-idiom     Control    Bilingual     7
# 7    0.604170   CH-idiom     Control    Bilingual     8
# 8    0.554433   CH-idiom     Control    Bilingual     9
# 9    1.147552   CH-idiom     Control    Bilingual    10
# 10   0.743643   CH-idiom     Control    Bilingual    11
# 11   0.739931   CH-idiom     Control    Bilingual    12
# 12   0.696994   CH-idiom     Control    Bilingual    13
# 13   0.738298   CH-idiom     Control    Bilingual    14
# 14   1.377690   CH-idiom     Control    Bilingual    15
# 15   0.741948   CH-idiom     Control    Bilingual    16
# ...
